# %%
# !pip install pandas-profiling
# !pip install --upgrade pandas-profiling
# Out:
# Collecting pandas-profiling
#   Using cached pandas_profiling-3.6.6-py2.py3-none-any.whl.metadata (4.5 kB)
# Collecting ydata-profiling (from pandas-profiling)
#   Using cached ydata_profiling-4.17.0-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: scipy<1.16,>=1.4.1 in c:\python310\lib\site-packages (from ydata-profiling->pandas-profiling) (1.15.3)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.1 in c:\python310\lib\site-packages (from ydata-profiling->pandas-profiling) (2.2.3)
# Collecting matplotlib<=3.10,>=3.5 (from ydata-profiling->pandas-profiling)
#   Using cached matplotlib-3.10.0-cp310-cp310-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: pydantic>=2 in c:\python310\lib\site-packages (from ydata-profiling->pandas-profiling) (2.11.5)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in c:\python310\lib\site-packages (from ydata-profiling->pandas-profiling) (6.0.2)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in c:\python310\lib\site-packages (from ydata-profiling->pandas-profiling) (3.1.6)
# Collecting visions<0.8.2,>=0.7.5 (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling->pandas-profiling)
#   Using cached visions-0.8.1-py3-none-any.whl.metadata (11 kB)
# Collecting numpy<2.2,>=1.16.0 (from ydata-profiling->pandas-profiling)
#   Using cached numpy-2.1.3-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: minify-html>=0.15.0 in c:\python310\lib\site-packages (from ydata-profiling->pandas-profiling) (0.18.1)
# Requirement already satisfied: filetype>=1.0.0 in c:\python310\lib\site-packages (from ydata-profiling->pandas-profiling) (1.2.0)
# Collecting phik<0.13,>=0.11.1 (from ydata-profiling->pandas-profiling)
#   Using cached phik-0.12.5-cp310-cp310-win_amd64.whl.metadata (5.6 kB)
# Requirement already satisfied: requests<3,>=2.24.0 in c:\python310\lib\site-packages (from ydata-profiling->pandas-profiling) (2.32.3)
# Requirement already satisfied: tqdm<5,>=4.48.2 in c:\python310\lib\site-packages (from ydata-profiling->pandas-profiling) (4.67.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in c:\python310\lib\site-packages (from ydata-profiling->pandas-profiling) (0.13.2)
# Collecting multimethod<2,>=1.4 (from ydata-profiling->pandas-profiling)
#   Using cached multimethod-1.12-py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in c:\python310\lib\site-packages (from ydata-profiling->pandas-profiling) (0.14.5)
# Collecting typeguard<5,>=3 (from ydata-profiling->pandas-profiling)
#   Using cached typeguard-4.4.4-py3-none-any.whl.metadata (3.3 kB)
# Collecting imagehash==4.3.1 (from ydata-profiling->pandas-profiling)
#   Using cached ImageHash-4.3.1-py2.py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: wordcloud>=1.9.3 in c:\python310\lib\site-packages (from ydata-profiling->pandas-profiling) (1.9.4)
# Collecting dacite>=1.8 (from ydata-profiling->pandas-profiling)
#   Using cached dacite-1.9.2-py3-none-any.whl.metadata (17 kB)
# Collecting numba<=0.61,>=0.56.0 (from ydata-profiling->pandas-profiling)
#   Using cached numba-0.61.0-cp310-cp310-win_amd64.whl.metadata (2.8 kB)
# Collecting PyWavelets (from imagehash==4.3.1->ydata-profiling->pandas-profiling)
#   Using cached pywavelets-1.8.0-cp310-cp310-win_amd64.whl.metadata (9.0 kB)
# Requirement already satisfied: pillow in c:\python310\lib\site-packages (from imagehash==4.3.1->ydata-profiling->pandas-profiling) (11.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\python310\lib\site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling->pandas-profiling) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\python310\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\python310\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python310\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\python310\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\python310\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\python310\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\python310\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in c:\python310\lib\site-packages (from numba<=0.61,>=0.56.0->ydata-profiling->pandas-profiling) (0.44.0)
# Requirement already satisfied: pytz>=2020.1 in c:\python310\lib\site-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling->pandas-profiling) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\python310\lib\site-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling->pandas-profiling) (2025.2)
# Requirement already satisfied: joblib>=0.14.1 in c:\python310\lib\site-packages (from phik<0.13,>=0.11.1->ydata-profiling->pandas-profiling) (1.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\python310\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\python310\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python310\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python310\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (2025.4.26)
# Requirement already satisfied: patsy>=0.5.6 in c:\python310\lib\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling->pandas-profiling) (1.0.2)
# Requirement already satisfied: colorama in c:\python310\lib\site-packages (from tqdm<5,>=4.48.2->ydata-profiling->pandas-profiling) (0.4.6)
# Collecting typing_extensions>=4.14.0 (from typeguard<5,>=3->ydata-profiling->pandas-profiling)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: attrs>=19.3.0 in c:\python310\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling->pandas-profiling) (25.3.0)
# Requirement already satisfied: networkx>=2.4 in c:\python310\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling->pandas-profiling) (3.4.2)
# Requirement already satisfied: puremagic in c:\python310\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling->pandas-profiling) (1.30)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\python310\lib\site-packages (from pydantic>=2->ydata-profiling->pandas-profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\python310\lib\site-packages (from pydantic>=2->ydata-profiling->pandas-profiling) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\python310\lib\site-packages (from pydantic>=2->ydata-profiling->pandas-profiling) (0.4.1)
# Requirement already satisfied: six>=1.5 in c:\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling) (1.17.0)
# Using cached pandas_profiling-3.6.6-py2.py3-none-any.whl (324 kB)
# Using cached ydata_profiling-4.17.0-py2.py3-none-any.whl (399 kB)
# Using cached ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
# Using cached matplotlib-3.10.0-cp310-cp310-win_amd64.whl (8.0 MB)
# Using cached multimethod-1.12-py3-none-any.whl (10 kB)
# Using cached numba-0.61.0-cp310-cp310-win_amd64.whl (2.8 MB)
# Using cached numpy-2.1.3-cp310-cp310-win_amd64.whl (12.9 MB)
# Using cached phik-0.12.5-cp310-cp310-win_amd64.whl (674 kB)
# Using cached typeguard-4.4.4-py3-none-any.whl (34 kB)
# Using cached visions-0.8.1-py3-none-any.whl (105 kB)
# Using cached dacite-1.9.2-py3-none-any.whl (16 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Using cached pywavelets-1.8.0-cp310-cp310-win_amd64.whl (4.2 MB)
# Installing collected packages: typing_extensions, numpy, multimethod, dacite, typeguard, PyWavelets, numba, visions, matplotlib, imagehash, phik, ydata-profiling, pandas-profiling
#
#   Attempting uninstall: typing_extensions
#
#     Found existing installation: typing_extensions 4.13.2
#
#     Uninstalling typing_extensions-4.13.2:
#
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#       Successfully uninstalled typing_extensions-4.13.2
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#    ----------------------------------------  0/13 [typing_extensions]
#   Attempting uninstall: numpy
#    ----------------------------------------  0/13 [typing_extensions]
#    --- ------------------------------------  1/13 [numpy]
#     Found existing installation: numpy 2.2.6
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#     Uninstalling numpy-2.2.6:
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#       Successfully uninstalled numpy-2.2.6
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    --- ------------------------------------  1/13 [numpy]
#    ------ ---------------------------------  2/13 [multimethod]
#    --------- ------------------------------  3/13 [dacite]
#    --------- ------------------------------  3/13 [dacite]
#    ------------ ---------------------------  4/13 [typeguard]
#    ------------ ---------------------------  4/13 [typeguard]
#    ------------ ---------------------------  4/13 [typeguard]
#    --------------- ------------------------  5/13 [PyWavelets]
#    --------------- ------------------------  5/13 [PyWavelets]
#    --------------- ------------------------  5/13 [PyWavelets]
#    --------------- ------------------------  5/13 [PyWavelets]
#    --------------- ------------------------  5/13 [PyWavelets]
#    --------------- ------------------------  5/13 [PyWavelets]
#    --------------- ------------------------  5/13 [PyWavelets]
#    --------------- ------------------------  5/13 [PyWavelets]
#    --------------- ------------------------  5/13 [PyWavelets]
#   Attempting uninstall: numba
#    --------------- ------------------------  5/13 [PyWavelets]
#     Found existing installation: numba 0.61.2
#    --------------- ------------------------  5/13 [PyWavelets]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#     Uninstalling numba-0.61.2:
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#       Successfully uninstalled numba-0.61.2
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    ------------------ ---------------------  6/13 [numba]
#    --------------------- ------------------  7/13 [visions]
#    --------------------- ------------------  7/13 [visions]
#    --------------------- ------------------  7/13 [visions]
#    --------------------- ------------------  7/13 [visions]
#    --------------------- ------------------  7/13 [visions]
#    --------------------- ------------------  7/13 [visions]
#    --------------------- ------------------  7/13 [visions]
#    --------------------- ------------------  7/13 [visions]
#    --------------------- ------------------  7/13 [visions]
#    --------------------- ------------------  7/13 [visions]
#    --------------------- ------------------  7/13 [visions]
#    --------------------- ------------------  7/13 [visions]
#    --------------------- ------------------  7/13 [visions]
#    --------------------- ------------------  7/13 [visions]
#    --------------------- ------------------  7/13 [visions]
#    --------------------- ------------------  7/13 [visions]
#    --------------------- ------------------  7/13 [visions]
#    --------------------- ------------------  7/13 [visions]
#    --------------------- ------------------  7/13 [visions]
#    --------------------- ------------------  7/13 [visions]
#    --------------------- ------------------  7/13 [visions]
#    --------------------- ------------------  7/13 [visions]
#    --------------------- ------------------  7/13 [visions]
#    --------------------- ------------------  7/13 [visions]
#    --------------------- ------------------  7/13 [visions]
#    --------------------- ------------------  7/13 [visions]
#    --------------------- ------------------  7/13 [visions]
#    --------------------- ------------------  7/13 [visions]
#    --------------------- ------------------  7/13 [visions]
#    --------------------- ------------------  7/13 [visions]
#    --------------------- ------------------  7/13 [visions]
#    --------------------- ------------------  7/13 [visions]
#    --------------------- ------------------  7/13 [visions]
#    --------------------- ------------------  7/13 [visions]
#    --------------------- ------------------  7/13 [visions]
#    --------------------- ------------------  7/13 [visions]
#    --------------------- ------------------  7/13 [visions]
#    --------------------- ------------------  7/13 [visions]
#    --------------------- ------------------  7/13 [visions]
#   Attempting uninstall: matplotlib
#    --------------------- ------------------  7/13 [visions]
#     Found existing installation: matplotlib 3.10.3
#    --------------------- ------------------  7/13 [visions]
#    ------------------------ ---------------  8/13 [matplotlib]
#    ------------------------ ---------------  8/13 [matplotlib]
#    ------------------------ ---------------  8/13 [matplotlib]
#     Uninstalling matplotlib-3.10.3:
#    ------------------------ ---------------  8/13 [matplotlib]
# ...
#    ------------------------ ---------------  8/13 [matplotlib]
#    ------------------------ ---------------  8/13 [matplotlib]
#    ------------------------ ---------------  8/13 [matplotlib]
#    ------------------------ ---------------  8/13 [matplotlib]
#    ------------------------ ---------------  8/13 [matplotlib]
#    ------------------------ ---------------  8/13 [matplotlib]
#    ------------------------ ---------------  8/13 [matplotlib]
#    ------------------------ ---------------  8/13 [matplotlib]
#    ------------------------ ---------------  8/13 [matplotlib]
#    ------------------------ ---------------  8/13 [matplotlib]
#    ------------------------ ---------------  8/13 [matplotlib]
#    ------------------------ ---------------  8/13 [matplotlib]
#    ------------------------ ---------------  8/13 [matplotlib]
#    ------------------------ ---------------  8/13 [matplotlib]
#    ------------------------ ---------------  8/13 [matplotlib]
#    ------------------------ ---------------  8/13 [matplotlib]
#    ------------------------ ---------------  8/13 [matplotlib]
#    ------------------------ ---------------  8/13 [matplotlib]
#    ------------------------ ---------------  8/13 [matplotlib]
#    ------------------------ ---------------  8/13 [matplotlib]
#    ------------------------ ---------------  8/13 [matplotlib]
#    ------------------------ ---------------  8/13 [matplotlib]
#    ------------------------ ---------------  8/13 [matplotlib]
#    ------------------------ ---------------  8/13 [matplotlib]
#    ------------------------ ---------------  8/13 [matplotlib]
#    ------------------------ ---------------  8/13 [matplotlib]
#    ------------------------ ---------------  8/13 [matplotlib]
#    ------------------------ ---------------  8/13 [matplotlib]
#    ------------------------ ---------------  8/13 [matplotlib]
#    ------------------------ ---------------  8/13 [matplotlib]
#    ------------------------ ---------------  8/13 [matplotlib]
#    ------------------------ ---------------  8/13 [matplotlib]
#    ------------------------ ---------------  8/13 [matplotlib]
#    ------------------------ ---------------  8/13 [matplotlib]
#    ------------------------ ---------------  8/13 [matplotlib]
#    ------------------------ ---------------  8/13 [matplotlib]
#    ------------------------ ---------------  8/13 [matplotlib]
#    --------------------------- ------------  9/13 [imagehash]
#    ------------------------------ --------- 10/13 [phik]
#    ------------------------------ --------- 10/13 [phik]
#    ------------------------------ --------- 10/13 [phik]
#    ------------------------------ --------- 10/13 [phik]
#    --------------------------------- ------ 11/13 [ydata-profiling]
#    --------------------------------- ------ 11/13 [ydata-profiling]
#    --------------------------------- ------ 11/13 [ydata-profiling]
#    --------------------------------- ------ 11/13 [ydata-profiling]
#    --------------------------------- ------ 11/13 [ydata-profiling]
#    --------------------------------- ------ 11/13 [ydata-profiling]
#    --------------------------------- ------ 11/13 [ydata-profiling]
#    --------------------------------- ------ 11/13 [ydata-profiling]
#    --------------------------------- ------ 11/13 [ydata-profiling]
#    --------------------------------- ------ 11/13 [ydata-profiling]
#    --------------------------------- ------ 11/13 [ydata-profiling]
#    --------------------------------- ------ 11/13 [ydata-profiling]
#    --------------------------------- ------ 11/13 [ydata-profiling]
#    --------------------------------- ------ 11/13 [ydata-profiling]
#    --------------------------------- ------ 11/13 [ydata-profiling]
#    --------------------------------- ------ 11/13 [ydata-profiling]
#    --------------------------------- ------ 11/13 [ydata-profiling]
#    --------------------------------- ------ 11/13 [ydata-profiling]
#    --------------------------------- ------ 11/13 [ydata-profiling]
#    --------------------------------- ------ 11/13 [ydata-profiling]
#    --------------------------------- ------ 11/13 [ydata-profiling]
#    --------------------------------- ------ 11/13 [ydata-profiling]
#    --------------------------------- ------ 11/13 [ydata-profiling]
#    --------------------------------- ------ 11/13 [ydata-profiling]
#    --------------------------------- ------ 11/13 [ydata-profiling]
#    --------------------------------- ------ 11/13 [ydata-profiling]
#    --------------------------------- ------ 11/13 [ydata-profiling]
#    --------------------------------- ------ 11/13 [ydata-profiling]
#    --------------------------------- ------ 11/13 [ydata-profiling]
#    --------------------------------- ------ 11/13 [ydata-profiling]
#    --------------------------------- ------ 11/13 [ydata-profiling]
#    --------------------------------- ------ 11/13 [ydata-profiling]
#    --------------------------------- ------ 11/13 [ydata-profiling]
#    --------------------------------- ------ 11/13 [ydata-profiling]
#    --------------------------------- ------ 11/13 [ydata-profiling]
#    --------------------------------- ------ 11/13 [ydata-profiling]
#    --------------------------------- ------ 11/13 [ydata-profiling]
#    --------------------------------- ------ 11/13 [ydata-profiling]
#    --------------------------------- ------ 11/13 [ydata-profiling]
#    --------------------------------- ------ 11/13 [ydata-profiling]
#    ------------------------------------ --- 12/13 [pandas-profiling]
#    ------------------------------------ --- 12/13 [pandas-profiling]
#    ------------------------------------ --- 12/13 [pandas-profiling]
#    ------------------------------------ --- 12/13 [pandas-profiling]
#    ------------------------------------ --- 12/13 [pandas-profiling]
#    ------------------------------------ --- 12/13 [pandas-profiling]
#    ------------------------------------ --- 12/13 [pandas-profiling]
#    ------------------------------------ --- 12/13 [pandas-profiling]
#    ------------------------------------ --- 12/13 [pandas-profiling]
#    ------------------------------------ --- 12/13 [pandas-profiling]
#    ------------------------------------ --- 12/13 [pandas-profiling]
#    ------------------------------------ --- 12/13 [pandas-profiling]
#    ------------------------------------ --- 12/13 [pandas-profiling]
#    ------------------------------------ --- 12/13 [pandas-profiling]
#    ------------------------------------ --- 12/13 [pandas-profiling]
#    ------------------------------------ --- 12/13 [pandas-profiling]
#    ------------------------------------ --- 12/13 [pandas-profiling]
#    ------------------------------------ --- 12/13 [pandas-profiling]
#    ------------------------------------ --- 12/13 [pandas-profiling]
#    ------------------------------------ --- 12/13 [pandas-profiling]
#    ------------------------------------ --- 12/13 [pandas-profiling]
#    ------------------------------------ --- 12/13 [pandas-profiling]
#    ------------------------------------ --- 12/13 [pandas-profiling]
#    ------------------------------------ --- 12/13 [pandas-profiling]
#    ------------------------------------ --- 12/13 [pandas-profiling]
#    ---------------------------------------- 13/13 [pandas-profiling]
#
# Successfully installed PyWavelets-1.8.0 dacite-1.9.2 imagehash-4.3.1 matplotlib-3.10.0 multimethod-1.12 numba-0.61.0 numpy-2.1.3 pandas-profiling-3.6.6 phik-0.12.5 typeguard-4.4.4 typing_extensions-4.15.0 visions-0.8.1 ydata-profiling-4.17.0
# WARNING: Ignoring invalid distribution -ensorflow (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\python310\lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-intel 2.18.0 requires ml-dtypes<0.5.0,>=0.4.0, but you have ml-dtypes 0.5.3 which is incompatible.
# tensorflow-intel 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 2.1.3 which is incompatible.
# tensorflow-intel 2.18.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3, but you have protobuf 6.31.0 which is incompatible.
# tensorflow-intel 2.18.0 requires tensorboard<2.19,>=2.18, but you have tensorboard 2.20.0 which is incompatible.
# Requirement already satisfied: pandas-profiling in c:\python310\lib\site-packages (3.6.6)
# Requirement already satisfied: ydata-profiling in c:\python310\lib\site-packages (from pandas-profiling) (4.17.0)
# Requirement already satisfied: scipy<1.16,>=1.4.1 in c:\python310\lib\site-packages (from ydata-profiling->pandas-profiling) (1.15.3)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.1 in c:\python310\lib\site-packages (from ydata-profiling->pandas-profiling) (2.2.3)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in c:\python310\lib\site-packages (from ydata-profiling->pandas-profiling) (3.10.0)
# Requirement already satisfied: pydantic>=2 in c:\python310\lib\site-packages (from ydata-profiling->pandas-profiling) (2.11.5)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in c:\python310\lib\site-packages (from ydata-profiling->pandas-profiling) (6.0.2)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in c:\python310\lib\site-packages (from ydata-profiling->pandas-profiling) (3.1.6)
# Requirement already satisfied: visions<0.8.2,>=0.7.5 in c:\python310\lib\site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling->pandas-profiling) (0.8.1)
# Requirement already satisfied: numpy<2.2,>=1.16.0 in c:\python310\lib\site-packages (from ydata-profiling->pandas-profiling) (2.1.3)
# Requirement already satisfied: minify-html>=0.15.0 in c:\python310\lib\site-packages (from ydata-profiling->pandas-profiling) (0.18.1)
# Requirement already satisfied: filetype>=1.0.0 in c:\python310\lib\site-packages (from ydata-profiling->pandas-profiling) (1.2.0)
# Requirement already satisfied: phik<0.13,>=0.11.1 in c:\python310\lib\site-packages (from ydata-profiling->pandas-profiling) (0.12.5)
# Requirement already satisfied: requests<3,>=2.24.0 in c:\python310\lib\site-packages (from ydata-profiling->pandas-profiling) (2.32.3)
# Requirement already satisfied: tqdm<5,>=4.48.2 in c:\python310\lib\site-packages (from ydata-profiling->pandas-profiling) (4.67.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in c:\python310\lib\site-packages (from ydata-profiling->pandas-profiling) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in c:\python310\lib\site-packages (from ydata-profiling->pandas-profiling) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in c:\python310\lib\site-packages (from ydata-profiling->pandas-profiling) (0.14.5)
# Requirement already satisfied: typeguard<5,>=3 in c:\python310\lib\site-packages (from ydata-profiling->pandas-profiling) (4.4.4)
# Requirement already satisfied: imagehash==4.3.1 in c:\python310\lib\site-packages (from ydata-profiling->pandas-profiling) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.3 in c:\python310\lib\site-packages (from ydata-profiling->pandas-profiling) (1.9.4)
# Requirement already satisfied: dacite>=1.8 in c:\python310\lib\site-packages (from ydata-profiling->pandas-profiling) (1.9.2)
# Requirement already satisfied: numba<=0.61,>=0.56.0 in c:\python310\lib\site-packages (from ydata-profiling->pandas-profiling) (0.61.0)
# Requirement already satisfied: PyWavelets in c:\python310\lib\site-packages (from imagehash==4.3.1->ydata-profiling->pandas-profiling) (1.8.0)
# Requirement already satisfied: pillow in c:\python310\lib\site-packages (from imagehash==4.3.1->ydata-profiling->pandas-profiling) (11.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\python310\lib\site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling->pandas-profiling) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\python310\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\python310\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python310\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\python310\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\python310\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\python310\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\python310\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in c:\python310\lib\site-packages (from numba<=0.61,>=0.56.0->ydata-profiling->pandas-profiling) (0.44.0)
# Requirement already satisfied: pytz>=2020.1 in c:\python310\lib\site-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling->pandas-profiling) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\python310\lib\site-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling->pandas-profiling) (2025.2)
# Requirement already satisfied: joblib>=0.14.1 in c:\python310\lib\site-packages (from phik<0.13,>=0.11.1->ydata-profiling->pandas-profiling) (1.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\python310\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\python310\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python310\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python310\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (2025.4.26)
# Requirement already satisfied: patsy>=0.5.6 in c:\python310\lib\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling->pandas-profiling) (1.0.2)
# Requirement already satisfied: colorama in c:\python310\lib\site-packages (from tqdm<5,>=4.48.2->ydata-profiling->pandas-profiling) (0.4.6)
# Requirement already satisfied: typing_extensions>=4.14.0 in c:\python310\lib\site-packages (from typeguard<5,>=3->ydata-profiling->pandas-profiling) (4.15.0)
# Requirement already satisfied: attrs>=19.3.0 in c:\python310\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling->pandas-profiling) (25.3.0)
# Requirement already satisfied: networkx>=2.4 in c:\python310\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling->pandas-profiling) (3.4.2)
# Requirement already satisfied: puremagic in c:\python310\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling->pandas-profiling) (1.30)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\python310\lib\site-packages (from pydantic>=2->ydata-profiling->pandas-profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\python310\lib\site-packages (from pydantic>=2->ydata-profiling->pandas-profiling) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\python310\lib\site-packages (from pydantic>=2->ydata-profiling->pandas-profiling) (0.4.1)
# Requirement already satisfied: six>=1.5 in c:\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling) (1.17.0)
# WARNING: Ignoring invalid distribution -ensorflow (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\python310\lib\site-packages)

# %%
# %pip install -q ydata-profiling
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ensorflow (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\python310\lib\site-packages)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from ydata_profiling import ProfileReport
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import warnings
warnings.filterwarnings('ignore')

# %%
try:
   df = pd.read_csv('diabetes.csv')
   print("✅ Dataset loaded successfully!")
except FileNotFoundError:
   print("⚠️ 'diabetes.csv' not found. Using dummy dataset for demo.")
   data = {
       'Pregnancies': [6, 1, 8, 1, 0],
       'Glucose': [148, 85, 183, 89, 137],
       'BloodPressure': [72, 66, 64, 66, 40],
       'SkinThickness': [35, 29, 0, 23, 35],
       'Insulin': [0, 0, 0, 94, 168],
       'BMI': [33.6, 26.6, 23.3, 28.1, 43.1],
       'DiabetesPedigreeFunction': [0.627, 0.351, 0.672, 0.167, 2.288],
       'Age': [50, 31, 32, 21, 33],
       'Outcome': [1, 0, 1, 0, 1]
   }
   df = pd.DataFrame(data)
print("\n📊 First 5 rows of the dataset:")
print(df.head())
print("\nℹ️ Dataset Info:")
df.info()
print("\n📈 Descriptive Statistics:")
print(df.describe().T)
# Out:
# ⚠️ 'diabetes.csv' not found. Using dummy dataset for demo.
#
# 📊 First 5 rows of the dataset:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
#
# ℹ️ Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               5 non-null      int64
#  1   Glucose                   5 non-null      int64
#  2   BloodPressure             5 non-null      int64
#  3   SkinThickness             5 non-null      int64
#  4   Insulin                   5 non-null      int64
#  5   BMI                       5 non-null      float64
#  6   DiabetesPedigreeFunction  5 non-null      float64
#  7   Age                       5 non-null      int64
#  8   Outcome                   5 non-null      int64
# dtypes: float64(2), int64(7)
# memory usage: 488.0 bytes
#
# 📈 Descriptive Statistics:
#                           count     mean        std     min     25%      50%  \
# Pregnancies                 5.0    3.200   3.563706   0.000   1.000    1.000
# Glucose                     5.0  128.400  41.458413  85.000  89.000  137.000
# BloodPressure               5.0   61.600  12.441865  40.000  64.000   66.000
# SkinThickness               5.0   24.400  14.518953   0.000  23.000   29.000
# Insulin                     5.0   52.400  76.372770   0.000   0.000    0.000
# BMI                         5.0   30.940   7.749387  23.300  26.600   28.100
# DiabetesPedigreeFunction    5.0    0.821   0.845657   0.167   0.351    0.627
# Age                         5.0   33.400  10.454664  21.000  31.000   32.000
# Outcome                     5.0    0.600   0.547723   0.000   0.000    1.000
#
#                               75%      max
# Pregnancies                 6.000    8.000
# Glucose                   148.000  183.000
# BloodPressure              66.000   72.000
# SkinThickness              35.000   35.000
# Insulin                    94.000  168.000
# BMI                        33.600   43.100
# DiabetesPedigreeFunction    0.672    2.288
# Age                        33.000   50.000
# Outcome                     1.000    1.000

# %%
profile = ProfileReport(df, title="Pima Diabetes Data Profiling Report", explorative=True)
print("\n✅ Pandas Profiling Report generated (use .to_notebook_iframe() or save to HTML).")

plt.figure(figsize=(6, 4))
sns.countplot(x='Outcome', data=df)
plt.title('Distribution of the Target Variable (Outcome)')
plt.xlabel('Outcome (0 = No Diabetes, 1 = Diabetes)')
plt.ylabel('Count')
plt.show()
print("\n🎯 Target Class Distribution:")
print(df['Outcome'].value_counts())
print(f"Percentage with Diabetes (1): {df['Outcome'].value_counts(normalize=True)[1]:.2%}")
# Out:
# ✅ Pandas Profiling Report generated (use .to_notebook_iframe() or save to HTML).
# 🎯 Target Class Distribution:
# Outcome
# 1    3
# 0    2
# Name: count, dtype: int64
# Percentage with Diabetes (1): 60.00%

# %%
df.hist(figsize=(15, 10), bins=20, edgecolor='black')
plt.suptitle('Histograms of All Features', y=1.02)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.show()

# %%
cols_with_zeros = ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']
print("\n🔍 Count of Zero values in key features:")
for col in cols_with_zeros:
   zero_count = (df[col] == 0).sum()
   print(f"{col}: {zero_count} ({(zero_count/len(df))*100:.2f}%)")
# Visualization of Zero-Value Distributions (excluding zeros)
plt.figure(figsize=(15, 10))
for i, col in enumerate(cols_with_zeros):
   plt.subplot(2, 3, i + 1)
   sns.histplot(df[df[col] != 0][col], kde=True, bins=20)
   plt.title(f'Distribution of {col} (Excluding 0s)')
plt.tight_layout()
plt.show()
# Out:
# 🔍 Count of Zero values in key features:
# Glucose: 0 (0.00%)
# BloodPressure: 0 (0.00%)
# SkinThickness: 1 (20.00%)
# Insulin: 3 (60.00%)
# BMI: 0 (0.00%)

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of All Features')
plt.show()

# %%
df_processed = df.copy()
for col in cols_with_zeros:
   median_val = df_processed[df_processed[col] != 0][col].median()
   df_processed[col] = df_processed[col].replace(0, median_val)
print("\n✅ Zero values imputed with the median of non-zero values.")
print("\n🔁 Checking for zero counts after imputation:")
for col in cols_with_zeros:
   print(f"{col}: {(df_processed[col] == 0).sum()}")
# Out:
# ✅ Zero values imputed with the median of non-zero values.
#
# 🔁 Checking for zero counts after imputation:
# Glucose: 0
# BloodPressure: 0
# SkinThickness: 0
# Insulin: 0
# BMI: 0

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
X = df_processed.drop('Outcome', axis=1)
y = df_processed['Outcome']
X_train, X_test, y_train, y_test = train_test_split(
   X, y, test_size=0.4, random_state=42, stratify=y
)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
X_train_scaled_df = pd.DataFrame(X_train_scaled, columns=X_train.columns)
print("\n📋 --- Preprocessing Summary ---")
print(f"Original X_train shape: {X_train.shape}")
print(f"Scaled X_train shape: {X_train_scaled.shape}")
print("\nFirst 5 rows of Scaled Training Data (Standardized):")
print(X_train_scaled_df.head())
# Out:
# 📋 --- Preprocessing Summary ---
# Original X_train shape: (3, 8)
# Scaled X_train shape: (3, 8)
#
# First 5 rows of Scaled Training Data (Standardized):
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0    -0.561951 -1.233338       0.790066      -1.372813 -1.224745 -0.403165
# 1     1.404879  1.215967       0.620766       0.392232  0.000000 -0.972340
# 2    -0.842927  0.017371      -1.410832       0.980581  1.224745  1.375505
#
#    DiabetesPedigreeFunction       Age
# 0                 -0.967620 -1.410220
# 1                 -0.409378  0.613139
# 2                  1.376997  0.797081

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
sns.histplot(X_train['Glucose'], kde=True)
plt.title('Glucose Distribution (Original)')
plt.subplot(1, 2, 2)
sns.histplot(X_train_scaled_df['Glucose'], kde=True)
plt.title('Glucose Distribution (Scaled/Standardized)')
plt.tight_layout()
plt.show()
print("\n✅ Data is now preprocessed and ready for training an Artificial Neural Network (ANN).")
# Out:
# ✅ Data is now preprocessed and ready for training an Artificial Neural Network (ANN).
